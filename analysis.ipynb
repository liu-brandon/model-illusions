# %%
import torch
import sklearn

import numpy as np
from pathlib import Path

# %% [markdown]
# ### Prepare data

# %%
def split_tokens_temporally(responses, tubelet_spatial_size=16, tubelet_temporal_size=2, video_size=384, video_frames=64):
    num_temporal_slices = int(video_frames / tubelet_temporal_size)
    tokens_per_slice = int((int(video_size / tubelet_spatial_size))**2)
    unflattened = torch.unflatten(responses, 0, (num_temporal_slices, tokens_per_slice))
    return unflattened

# %%
MODEL_RESPONSES = "/scratch/users/liubr/model-illusions/model_response/vjepa"

import re

control = None
bistable = None

left_control = None
right_control = None

by_rotation_vel_control = {}
by_rotation_vel_bistable = {}

responses_separated_control = []

responses_by_time = {}

for file in Path(MODEL_RESPONSES).iterdir():
    responses = torch.squeeze(torch.load(file, map_location="cpu"))
    responses -= torch.mean(responses, dim=0)
    response_unflattened = split_tokens_temporally(responses)
    responses = torch.mean(response_unflattened, dim=1)
    print(responses.shape)
    if "depth_0_" in file.name:
        if control is None:
            control = responses
        else:
            control = torch.vstack((control, responses))
        
        if "omega_-" in file.name:
            if left_control is None:
                left_control = responses
            else:
                left_control = torch.vstack((left_control, responses))
        else:
            if right_control is None:
                right_control = responses
            else:
                right_control = torch.vstack((right_control, responses))
        
        velocity_match = re.search(r"omega_(-?\d+\.?\d*)_seed", file.name)
        velocity = float(velocity_match.group(1))
        if velocity not in by_rotation_vel_control.keys():
            by_rotation_vel_control[velocity] = responses
        else:
            by_rotation_vel_control[velocity] = torch.vstack((by_rotation_vel_control[velocity], responses))

        if "_seed_0" in file.name:
            responses_separated_control.append(responses)
        
    else:
        if bistable is None:
            bistable = responses
        else:
            bistable = torch.vstack((bistable, responses))
# Out:
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])
# torch.Size([32, 1408])

# %%
# control_reshaped = control.reshape(32, -1, 1408)

# %%
# control_reshaped -= control_reshaped.mean(dim=0).unsqueeze(0)

# %%
# control = control_reshaped.reshape(-1, 1408)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=20)
pca.fit(control)
# Out:
# PCA(n_components=20)

# %%
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.58717984 0.19105988 0.0629237  0.03095744 0.02589394 0.01890907
#  0.01335881 0.00897923 0.00584731 0.00448847 0.00378836 0.00342093
#  0.00325082 0.00279028 0.0023825  0.00222111 0.00187749 0.00158185
#  0.00144819 0.0013075 ]
# 0.9736667235767679

# %%
left_control_projected = pca.transform(left_control)
right_control_projected = pca.transform(right_control)

# %%
print(right_control_projected.shape)
print(left_control_projected.shape)
# Out:
# (4000, 20)
# (4800, 20)

# %% [markdown]
# ### Project CW and CCW

# %% [markdown]
# PC 1 and 2

# %%
import matplotlib.pyplot as plt

plt.scatter(left_control_projected[:, 0], left_control_projected[:, 1], alpha=.3)
plt.scatter(right_control_projected[:, 0], right_control_projected[:, 1], alpha=.3)
# control_projected.shape

plt.show()

# %% [markdown]
# PC 3 and 4

# %%
import matplotlib.pyplot as plt

x_comp, y_comp = 3, 4
plt.scatter(left_control_projected[:, x_comp], left_control_projected[:, y_comp], alpha=.3, label="CW")
plt.scatter(right_control_projected[:, x_comp], right_control_projected[:, y_comp], alpha=.3, label="CCW")
# control_projected.shape

plt.title("Clockwise/Counterclockwise rotation on PC 3 and 4")
plt.xlabel("PC 3")
plt.ylabel("PC 4")
plt.legend()
plt.show()

# %% [markdown]
# ### Project Velocity Magnitude

# %%
by_rotation_vel_control_projected = {k: pca.transform(v) for k, v in by_rotation_vel_control.items()}

# %%
print(by_rotation_vel_control_projected)
# Out:
# {0.3999999999999998: array([[ 2.25052274e+01,  1.57704322e+01,  1.00557841e+01, ...,
#         -2.00342347e-02, -8.81773871e-01,  9.37078416e-01],
#        [ 2.18656139e+01,  8.58575929e+00, -5.31619344e+00, ...,
#         -1.45399739e+00, -1.34577215e+00, -1.38118151e+00],
#        [ 2.01509052e+01,  6.04914089e+00, -5.49307687e+00, ...,
#          1.59940448e+00,  6.47172346e-01,  8.03505521e-01],
#        ...,
#        [-2.29526921e+01,  1.41252058e+01, -6.27359877e+00, ...,
#          6.84870945e-01, -9.58467991e-01,  4.00908701e-01],
#        [-2.21628607e+01,  1.84005986e+01, -1.14885415e+01, ...,
#          2.80726966e-01,  6.45093384e-01, -3.44236659e-01],
#        [-2.43418102e+01,  2.17274417e+01,  1.71984993e+00, ...,
#         -1.30716139e-01, -1.06427840e+00,  3.98239699e-01]],
#       shape=(800, 20)), -0.30000000000000004: array([[ 23.35590058,  14.91303379,  12.043747  , ...,   0.79119232,
#           0.21291527,   1.2206943 ],
#        [ 21.45407165,   8.14258359,  -4.05540377, ...,   0.6176702 ,
#           0.29906102,   0.47867825],
#        [ 20.20802406,   5.17438278,  -7.58135095, ...,  -0.04086565,
#           0.20051144,   0.43243581],
#        ...,
#        [-22.28427457,  15.44531247,  -6.92563444, ...,   1.08040554,
#          -1.21431555,   0.73634378],
#        [-22.21126271,  17.29455886,  -9.53123975, ...,  -0.25623824,
#           0.05925115,  -0.14315208],
#        [-24.48003623,  21.68452925,   1.14071064, ...,   0.23650697,
#          -0.9031855 ,  -0.27165429]], shape=(800, 20)), -0.20000000000000007: array([[ 23.95740829,  15.04542314,  12.99336294, ...,   0.31683476,
#           0.73693094,  -0.24924615],
#        [ 22.10343328,   7.2377829 ,  -5.8411945 , ...,   0.30623853,
#          -0.27156393,  -0.25451705],
#        [ 20.40133498,   5.29034789,  -7.73671868, ...,   1.22662267,
#          -0.30818789,   1.46234237],
#        ...,
#        [-22.75460434,  15.09277465,  -6.76188844, ...,  -0.3642426 ,
#          -0.4943439 ,  -0.79559849],
#        [-21.80290095,  17.219119  , -10.52884592, ...,  -0.6919627 ,
#           0.68318188,   0.13542236],
#        [-24.02838192,  21.25297442,   1.09257017, ...,  -0.44149771,
#          -0.24912812,  -0.4204573 ]], shape=(800, 20)), -0.4: array([[ 22.83909554,  14.97334122,  10.89431783, ...,   1.06874848,
#          -0.07569473,   1.41743359],
#        [ 21.24506906,   8.0855568 ,  -4.95043822, ...,  -0.50118408,
#           0.29447005,  -0.77984745],
#        [ 19.85820962,   6.1500578 ,  -5.97541516, ...,   0.25032226,
#           0.39688095,   0.54003329],
#        ...,
#        [-22.75074674,  14.94208464,  -6.79029398, ...,   0.57760517,
#          -1.05835299,  -0.30647109],
#        [-21.88601193,  18.99310779, -10.69714265, ...,   0.07550711,
#           0.74224235,   0.24188444],
#        [-24.32490184,  22.30798645,   0.64448651, ...,   0.22440382,
#          -0.78336468,  -0.07904028]], shape=(800, 20)), 0.19999999999999984: array([[ 2.39746757e+01,  1.51510724e+01,  1.36543126e+01, ...,
#         -6.70293484e-02,  7.06590017e-01,  2.32313001e-01],
#        [ 2.20301277e+01,  7.59226202e+00, -5.05596164e+00, ...,
#         -1.07948569e+00, -3.76122481e-03, -3.59703581e-01],
#        [ 1.98893382e+01,  5.42187567e+00, -8.85323341e+00, ...,
#          4.62312956e-01,  1.82070203e-01,  1.20165136e+00],
#        ...,
#        [-2.24680621e+01,  1.52528257e+01, -6.17480851e+00, ...,
#         -5.95966731e-01, -6.83223083e-01,  4.58622521e-01],
#        [-2.19548823e+01,  1.69286497e+01, -9.96512531e+00, ...,
#         -7.10132749e-01,  9.73169296e-01,  6.75478230e-01],
#        [-2.38997658e+01,  2.09270370e+01,  1.48891216e+00, ...,
#         -7.95830424e-01, -2.88217452e-01, -5.33632147e-01]],
#       shape=(800, 20)), 0.49999999999999967: array([[ 2.28519945e+01,  1.55609033e+01,  8.92257097e+00, ...,
#         -9.24246284e-01, -1.16821951e+00,  1.09802558e-01],
#        [ 2.21094873e+01,  8.68414056e+00, -4.63007132e+00, ...,
#         -7.79521293e-01,  5.03940278e-01, -1.64373911e+00],
#        [ 2.07239116e+01,  6.48160160e+00, -6.51623037e+00, ...,
#          5.59214182e-02,  7.80818893e-01, -1.26723395e+00],
#        ...,
#        [-2.26617446e+01,  1.44819381e+01, -5.59235118e+00, ...,
#          1.06540551e+00, -2.31928494e-01,  5.85053945e-01],
#        [-2.19609740e+01,  1.90962837e+01, -1.06917101e+01, ...,
#          2.81399320e-01,  1.73335697e+00,  1.16638902e+00],
#        [-2.40301652e+01,  2.24544188e+01,  8.00984525e-01, ...,
#         -2.34062200e-01, -5.51173231e-01,  1.69023260e-02]],
#       shape=(800, 20)), -0.10000000000000009: array([[ 2.37729045e+01,  1.46035758e+01,  1.55294369e+01, ...,
#          9.81046367e-01,  6.03554907e-01, -4.93836090e-01],
#        [ 2.12573762e+01,  7.17741139e+00, -5.65806468e+00, ...,
#          1.11075336e+00, -7.77121011e-01, -2.66765356e-03],
#        [ 1.96408643e+01,  5.42571435e+00, -8.35512366e+00, ...,
#          7.58136874e-01, -2.37387113e+00,  1.81804683e+00],
#        ...,
#        [-2.25564600e+01,  1.55828095e+01, -5.52426793e+00, ...,
#         -2.00343676e-01, -5.92656976e-01,  1.47902520e+00],
#        [-2.21040907e+01,  1.70320994e+01, -1.04954549e+01, ...,
#         -9.02188270e-01,  6.00939494e-01,  1.30999794e+00],
#        [-2.41379419e+01,  2.00099195e+01,  2.28373074e+00, ...,
#         -8.22014136e-01, -1.98152340e-01,  3.57565480e-01]],
#       shape=(800, 20)), -0.5: array([[ 22.7345016 ,  15.0498331 ,   8.25740204, ...,  -1.78619379,
#          -0.30031023,   0.54361491],
#        [ 21.90232025,   8.92628849,  -3.60625088, ...,  -1.35067384,
#           0.81868984,   0.72187011],
#        [ 20.5435609 ,   6.37758619,  -6.9405182 , ...,  -1.02202409,
#           0.46545166,  -0.62277586],
#        ...,
#        [-23.36041671,  14.41065151,  -6.55418547, ...,   0.84152193,
#          -0.03067311,   0.50380242],
#        [-22.57978817,  18.21923503, -10.11615064, ...,  -0.33218092,
#           1.11858941,   0.09428665],
#        [-24.64613107,  22.68070251,   1.29039228, ...,   0.17149186,
#          -0.78883019,   0.35587594]], shape=(800, 20)), 0.09999999999999987: array([[ 23.98203054,  14.53285328,  16.49747056, ...,   1.16658817,
#           0.91142703,  -0.91084389],
#        [ 21.83112129,   6.72406528,  -5.33948305, ...,   0.40835713,
#          -1.28923959,  -0.28649578],
#        [ 19.39392036,   4.99851247,  -8.09845557, ...,   1.32598728,
#          -2.23384504,   1.39575009],
#        ...,
#        [-22.52227562,  15.78685588,  -6.69861573, ...,  -0.3994917 ,
#          -1.13695458,   0.56894685],
#        [-21.71576433,  17.31817364, -10.13182799, ...,  -1.11505971,
#           0.63711866,   0.45111326],
#        [-23.61872741,  19.99854263,   2.28204493, ...,  -0.3447873 ,
#          -0.26050585,  -0.25664148]], shape=(800, 20)), 0.2999999999999998: array([[ 23.13010699,  15.48546754,  11.38543121, ...,   0.4417657 ,
#          -0.90532934,   0.12537465],
#        [ 21.5344403 ,   8.39802279,  -3.92936992, ...,   0.51127441,
#          -0.58009781,  -0.29589044],
#        [ 20.63213963,   5.06005638,  -5.97325749, ...,   0.40068664,
#          -0.14155398,   0.58197198],
#        ...,
#        [-22.89233611,  15.49266657,  -5.98845464, ...,  -0.3270241 ,
#          -0.87408932,   0.42245924],
#        [-21.8038617 ,  17.63322281, -11.16424957, ...,  -0.79891921,
#           1.030353  ,   0.10048442],
#        [-24.02577351,  22.28842656,   1.10053729, ...,  -0.07042076,
#          -0.04813812,   0.24817873]], shape=(800, 20)), -0.6: array([[ 22.44482867,  15.74161279,   7.23779331, ...,  -0.70075624,
#          -1.00459003,  -0.36116646],
#        [ 21.96570247,   9.10671851,  -3.7342588 , ...,  -0.96531469,
#           1.25214789,   0.29014658],
#        [ 20.44301447,   6.73072073,  -5.46839901, ...,   1.06805435,
#           2.0569958 ,   0.73110813],
#        ...,
#        [-22.87475727,  14.59624052,  -7.11655224, ...,   0.72665034,
#          -0.14422267,  -0.33759342],
#        [-22.6155652 ,  17.92913239,  -9.65455801, ...,   1.09503292,
#           1.3978259 ,   0.30269823],
#        [-23.44439147,  23.33967533,   0.4011265 , ...,  -0.52480909,
#          -0.3404652 ,   0.21505239]], shape=(800, 20))}

# %% [markdown]
# PC 1 and 2

# %%
for k, v in by_rotation_vel_control_projected.items():
    plt.scatter(v[:, 0], v[:, 1], alpha=.3, label=str(k))
# control_projected.shape
plt.legend()
plt.show()

# %% [markdown]
# PC 3 and 4

# %%
x_comp, y_comp = 2, 3
combined_matrix = None
coloring = None
for k, v in by_rotation_vel_control_projected.items():
    k = abs(k)
    if combined_matrix is None:
        combined_matrix = v
        coloring = np.ones((v.shape[0])) * k
    else:
        combined_matrix = np.vstack((combined_matrix, v))
        coloring = np.hstack((coloring, np.ones((v.shape[0])) * k))

plt.scatter(combined_matrix[:, x_comp], combined_matrix[:, y_comp], c=coloring, cmap="viridis", alpha=.3, label=str(k))
cbar = plt.colorbar()
cbar.set_label("rotation speed")
plt.title("V-JEPA responses projected on PC 3 and 4")
plt.xlabel("PC 3")
plt.ylabel("PC 4")
# control_projected.shape
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### Project Per Stimulus (seed 0)

# %% [markdown]
# PC 1 and 2

# %%
for i, responses in enumerate(responses_separated_control):
    response_projected = pca.transform(responses)
    plt.scatter(response_projected[:, 0], response_projected[:, 1], alpha=.3, label=str(i))

plt.legend()
plt.show()

# %% [markdown]
# PC 2 and 3

# %%
for i, responses in enumerate(responses_separated_control):
    response_projected = pca.transform(responses)
    plt.scatter(response_projected[:, 2], response_projected[:, 3], alpha=.3, label=str(i))

plt.legend()
plt.show()

# %% [markdown]
# ## Project frame timing on first two PCs

# %%
n_stimuli = control.shape[0] // 32
control_by_time = control.reshape(n_stimuli, 32, 1408).transpose(0, 1)
control_by_time.shape
# Out:
# torch.Size([32, 275, 1408])

# %%
response_projected = pca.transform(control)
frame_idx = np.tile(np.arange(32), n_stimuli)

plt.title("V-JEPA 2 responses projected on PC 1 and 2")
plt.scatter(response_projected[:, 0], response_projected[:, 1], c=frame_idx, alpha=.3, cmap='viridis', label=str(i))
cbar = plt.colorbar()
cbar.set_label("frame number")
plt.xlabel("PC 1")
plt.ylabel("PC 2")
# Out:
# Text(0, 0.5, 'PC 2')

# %% [markdown]
# First two PCs seem to encode time in the video.

# %%
response_projected = pca.transform(control)
frame_idx = np.tile(np.arange((32)), n_stimuli)

plt.scatter(response_projected[:, 2], response_projected[:, 3], c=frame_idx, alpha=.3, cmap='viridis', label=str(i))
cbar = plt.colorbar()
cbar.set_label("frame number")

plt.title("V-JEPA 2 responses projected on PC 3 and 4")
plt.xlabel("PC 3")
plt.ylabel("PC 4")
# Out:
# Text(0, 0.5, 'PC 4')

# %% [markdown]
# ### Mean CW and CCW difference vector

# %%
cw_mean = left_control.mean(dim=0)
ccw_mean = right_control.mean(dim=0)
rotation_axis = cw_mean - ccw_mean

print(rotation_axis)
# Out:
# tensor([-3.0547e-09,  1.3212e-09, -2.1954e-09,  ...,  7.8579e-09,
#          8.5433e-10,  2.4341e-08])

# %%
proj_cw_on_rotation_axis = left_control @ rotation_axis
proj_ccw_on_rotation_axis = right_control @ rotation_axis

# %%
left_control.mean()
# Out:
# tensor(-3.5221e-10)

# %%
rotation_axis.min()
# Out:
# tensor(-1.8454e-07)

# %%
torch.nn.functional.cosine_similarity(cw_mean.unsqueeze(0), ccw_mean.unsqueeze(0))
# Out:
# tensor([0.1418])

# %%
ccw_mean.norm()
# Out:
# tensor(4.6297e-07)

# %%
cw_mean.norm()
# Out:
# tensor(4.0669e-07)

# %% [markdown]
# ## Linear classifier

# %%
from sklearn.model_selection import train_test_split, cross_validate, KFold

folds = 5

X = torch.vstack((left_control, right_control))
y = torch.hstack((torch.ones(left_control.shape[0]), torch.zeros(right_control.shape[0])))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=(1/folds), random_state=0, stratify=y)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA

classifier = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=25)),
    ('svm', LinearSVC())
])

# %%
cv = KFold(n_splits=(folds - 1))
scores = cross_validate(classifier, X_train, y_train, cv=cv, return_train_score=True)

# %%
scores
# Out:
# {'fit_time': array([2.49863052, 2.70799875, 2.69199848, 3.51084447]),
#  'score_time': array([0.01470757, 0.01656342, 0.01491618, 0.01538539]),
#  'test_score': array([0.52443182, 0.54829545, 0.52840909, 0.53806818]),
#  'train_score': array([0.55056818, 0.53863636, 0.55037879, 0.54545455])}

# %% [markdown]
# Group K-Fold

# %%
from sklearn.model_selection import GroupKFold
gkf = GroupKFold(n_splits=folds)
groups = np.arange(control.shape[0] // 32)
np.random.shuffle(groups)
groups = np.repeat(groups, 32)

scores = cross_validate(classifier, X, y, cv=gkf, groups=groups, return_train_score=True)

# %%
scores
# Out:
# {'fit_time': array([3.90152478, 3.1230948 , 3.37738585, 3.02506256, 3.23655581]),
#  'score_time': array([0.01545286, 0.01514363, 0.01511192, 0.01518035, 0.02010798]),
#  'test_score': array([0.52727273, 0.52727273, 0.56363636, 0.52727273, 0.58181818]),
#  'train_score': array([0.55      , 0.55      , 0.54090909, 0.55      , 0.53636364])}
